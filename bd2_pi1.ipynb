# %% [markdown]
# # Projeto de Implementação 1
# ### **Banco de Dados II (2022-1) - Prof. Altigran Soares da Silva**
# - Aluno: Glenn de Aguiar Oliveira da Fonseca
# - Matrícula: 21953825
# - Data de Entrega: 14/11/2022

# %% [markdown]
# # Parte 1: Criação do Cluster Virtual Hadoop
#
# ### Hadoop Instalation Part
# Hadoop is a Java-based programming framework that supports the processing and storage of extremely large datasets on a cluster of inexpensive machines. It was the first major open source project in the big data playing field and is sponsored by the Apache Software Foundation.

# %% [markdown]
# ## Step 1: Installing Hadoop

# %%
# !wget https://downloads.apache.org/hadoop/common/hadoop-3.3.4/hadoop-3.3.4.tar.gz
# Out:
# --2022-11-14 23:07:52--  https://downloads.apache.org/hadoop/common/hadoop-3.3.4/hadoop-3.3.4.tar.gz
# Resolving downloads.apache.org (downloads.apache.org)... 88.99.95.219, 135.181.214.104, 2a01:4f9:3a:2c57::2, ...
# Connecting to downloads.apache.org (downloads.apache.org)|88.99.95.219|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 695457782 (663M) [application/x-gzip]
# Saving to: ‘hadoop-3.3.4.tar.gz’
#
# hadoop-3.3.4.tar.gz 100%[===================>] 663.24M  12.5MB/s    in 55s
#
# 2022-11-14 23:08:47 (12.1 MB/s) - ‘hadoop-3.3.4.tar.gz’ saved [695457782/695457782]

# %% [markdown]
# we’ll use the tar command with the -x flag to extract, -z to uncompress, -v for verbose output, and -f to specify that we’re extracting from a file

# %%
# !tar -xzvf hadoop-3.3.4.tar.gz
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# hadoop-3.3.4/share/doc/hadoop/hadoop-yarn/hadoop-yarn-server/hadoop-yarn-server-nodemanager/apidocs/org/apache/hadoop/yarn/server/nodemanager/containermanager/resourceplugin/deviceframework/package-tree.html
# hadoop-3.3.4/share/doc/hadoop/hadoop-yarn/hadoop-yarn-server/hadoop-yarn-server-nodemanager/apidocs/org/apache/hadoop/yarn/server/nodemanager/containermanager/resourceplugin/deviceframework/DeviceMappingManager.html
# hadoop-3.3.4/share/doc/hadoop/hadoop-yarn/hadoop-yarn-server/hadoop-yarn-server-nodemanager/apidocs/org/apache/hadoop/yarn/server/nodemanager/containermanager/resourceplugin/deviceframework/DeviceResourceHandlerImpl.html
# hadoop-3.3.4/share/doc/hadoop/hadoop-yarn/hadoop-yarn-server/hadoop-yarn-server-nodemanager/apidocs/org/apache/hadoop/yarn/server/nodemanager/containermanager/resourceplugin/deviceframework/ShellWrapper.html
# ...

# %%
#copy  hadoop file to user/local
# !cp -r hadoop-3.3.4/ /usr/local/

# %% [markdown]
# ## Step 2: Configuring Hadoop’s Java Home
# Hadoop requires that you set the path to Java, either as an environment variable or in the Hadoop configuration file.

# %%
#To find the default Java path
# !readlink -f /usr/bin/java | sed "s:bin/java::"
# Out:
# /usr/lib/jvm/java-11-openjdk-amd64/

# %% [markdown]
# To set java path, go to /usr/local/hadoop-3.3.4/etc/hadoop/hadoop-env.sh then
#
# . . .
# export JAVA_HOME=/usr/lib/jvm/java-11-openjdk-amd64/
#  . . .

# %%
# !echo 'export JAVA_HOME=/usr/lib/jvm/java-11-openjdk-amd64/' >> /usr/local/hadoop-3.3.4/etc/hadoop/hadoop-env.sh

# %% [markdown]
# ## Step 3:  Running Hadoop

# %%
#Running Hadoop
# !/usr/local/hadoop-3.3.4/bin/hadoop
# Out:
# Usage: hadoop [OPTIONS] SUBCOMMAND [SUBCOMMAND OPTIONS]
#  or    hadoop [OPTIONS] CLASSNAME [CLASSNAME OPTIONS]
#   where CLASSNAME is a user-provided Java class
#
#   OPTIONS is none or any of:
#
# buildpaths                       attempt to add class files from build tree
# --config dir                     Hadoop config directory
# --debug                          turn on shell script debug mode
# --help                           usage information
# hostnames list[,of,host,names]   hosts to use in slave mode
# hosts filename                   list of hosts to use in slave mode
# loglevel level                   set the log4j level for this command
# workers                          turn on worker mode
#
#   SUBCOMMAND is one of:
#
#
#     Admin Commands:
#
# daemonlog     get/set the log level for each daemon
#
#     Client Commands:
#
# archive       create a Hadoop archive
# checknative   check native Hadoop and compression libraries availability
# ...

# %%
# !mkdir ~/input
# !cp /usr/local/hadoop-3.3.4/etc/hadoop/*.xml ~/input

# %%
# !ls ~/input
# Out:
# capacity-scheduler.xml	hdfs-rbf-site.xml  kms-acls.xml     yarn-site.xml
# core-site.xml		hdfs-site.xml	   kms-site.xml
# hadoop-policy.xml	httpfs-site.xml    mapred-site.xml

# %%
# !/usr/local/hadoop-3.3.4/bin/hadoop jar /usr/local/hadoop-3.3.4/share/hadoop/mapreduce/hadoop-mapreduce-examples-3.3.4.jar grep ~/input ~/grep_example 'allowed[.]*'
# Out:
# 2022-11-14 23:09:27,429 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2022-11-14 23:09:27,688 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2022-11-14 23:09:27,688 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2022-11-14 23:09:27,983 INFO input.FileInputFormat: Total input files to process : 10
# 2022-11-14 23:09:28,019 INFO mapreduce.JobSubmitter: number of splits:10
# 2022-11-14 23:09:28,466 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local1996551676_0001
# 2022-11-14 23:09:28,466 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2022-11-14 23:09:28,819 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 2022-11-14 23:09:28,820 INFO mapreduce.Job: Running job: job_local1996551676_0001
# 2022-11-14 23:09:28,842 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# ...

# %%
# !cat ~/grep_example/*
# Out:
# 22	allowed.
# 1	allowed

# %% [markdown]
# # Parte 2: Contagem de Palavras em Coleções de Texto

# %% [markdown]
# ## Baixar Arquivos

# %% [markdown]
# ### Coleções
#
# - `shakespeare.txt`: contém as “Obras Completas de William Shakespeare” do
# Project Gutenberg.
# - `p2p-Gnutella08.txt`:contém um instantâneo da rede de compartilhamento de arquivos peer-to-peer Gnutella de agosto de 2002, onde os nós representam hosts na topologia da rede Gnutella e as arestas representam conexões entre os hosts Gnutella.

# %%
# !wget https://github.com/glenn-f/BD2-PI1/raw/master/dados/shakespeare.txt
# !wget https://github.com/glenn-f/BD2-PI1/raw/master/dados/p2p-Gnutella08.txt
# Out:
# --2022-11-14 23:09:32--  https://github.com/glenn-f/BD2-PI1/raw/master/dados/shakespeare.txt
# Resolving github.com (github.com)... 20.27.177.113
# Connecting to github.com (github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/glenn-f/BD2-PI1/master/dados/shakespeare.txt [following]
# --2022-11-14 23:09:32--  https://raw.githubusercontent.com/glenn-f/BD2-PI1/master/dados/shakespeare.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 122780 (120K) [text/plain]
# Saving to: ‘shakespeare.txt’
#
# shakespeare.txt     100%[===================>] 119.90K  --.-KB/s    in 0.03s
#
# 2022-11-14 23:09:33 (4.49 MB/s) - ‘shakespeare.txt’ saved [122780/122780]
#
# ...

# %% [markdown]
# ### Mapper e Reducer para Contagem de Palavras
#
# - **mapper.py:** mapper inicial que implementa a versão 2 do contador que foi visto em sala de aula.
# - **mapper2.py:** alteração do mapper inicial para aceitar apenas a expressão regular `[A-Za-z]+`.
# - **mapper2_p2p.py:** alteração do mapper inicial para aceitar apenas a expressão regular `[0-9]+` e ignorar comentários (iniciados com `#`). Aplicado apenas na coleção `p2p-Gnutella08.txt`.
# - **reducer.py:** reducer para o contador de palavras.

# %%
# !wget https://github.com/glenn-f/BD2-PI1/raw/master/mapper.py
# !wget https://github.com/glenn-f/BD2-PI1/raw/master/mapper2.py
# !wget https://github.com/glenn-f/BD2-PI1/raw/master/mapper2_p2p.py
# !wget https://github.com/glenn-f/BD2-PI1/raw/master/reducer.py
# Out:
# --2022-11-14 23:09:34--  https://github.com/glenn-f/BD2-PI1/raw/master/mapper.py
# Resolving github.com (github.com)... 20.27.177.113
# Connecting to github.com (github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/glenn-f/BD2-PI1/master/mapper.py [following]
# --2022-11-14 23:09:35--  https://raw.githubusercontent.com/glenn-f/BD2-PI1/master/mapper.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 855 [text/plain]
# Saving to: ‘mapper.py’
#
# mapper.py           100%[===================>]     855  --.-KB/s    in 0s
#
# 2022-11-14 23:09:35 (35.1 MB/s) - ‘mapper.py’ saved [855/855]
#
# ...

# %% [markdown]
# ## Executar MapReduce nas Coleções

# %% [markdown]
# Limpar pasta de saída, caso haja algum conteúdo.

# %%
# !rm -r /content/output/
# Out:
# rm: cannot remove '/content/output/': No such file or directory

# %% [markdown]
# ### MapReduce na coleção `shakespeare.txt`.

# %% [markdown]
# #### Versão Inicial
#
# MapReduce apresentado em sala de aula (versão 2)

# %%
# !/usr/local/hadoop-3.3.4/bin/hadoop jar /usr/local/hadoop-3.3.4/share/hadoop/tools/lib/hadoop-streaming-3.3.4.jar -input /content/shakespeare.txt -output /content/output/shakespeare1 -file /content/mapper.py  -file /content/reducer.py  -mapper 'python mapper.py'  -reducer 'python reducer.py'
# Out:
# 2022-11-14 23:09:39,977 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [/content/mapper.py, /content/reducer.py] [] /tmp/streamjob2820462339417750776.jar tmpDir=null
# 2022-11-14 23:09:40,791 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2022-11-14 23:09:41,002 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2022-11-14 23:09:41,002 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2022-11-14 23:09:41,034 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2022-11-14 23:09:41,192 INFO mapred.FileInputFormat: Total input files to process : 1
# 2022-11-14 23:09:41,214 INFO mapreduce.JobSubmitter: number of splits:1
# 2022-11-14 23:09:41,514 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local1106455426_0001
# 2022-11-14 23:09:41,514 INFO mapreduce.JobSubmitter: Executing with tokens: []
# ...

# %%
# !ls /content/output/shakespeare1/
# Out:
# part-00000  _SUCCESS

# %%
# !head -n 15 /content/output/shakespeare1/part-00000
# Out:
# "defects,"	1
# "information	1
# "plain	2
# "project	5
# "right	1
# #1041]	1
# $5,000)	1
# ''tis	1
# 'amen'	1
# 'as-is',	1
# 'fair,	2
# 'fore	1
# 'gainst	6
# 'greeing,	1
# 'had	1

# %% [markdown]
# #### Versão Modificada

# %%
# !/usr/local/hadoop-3.3.4/bin/hadoop jar /usr/local/hadoop-3.3.4/share/hadoop/tools/lib/hadoop-streaming-3.3.4.jar -input /content/shakespeare.txt -output /content/output/shakespeare2 -file /content/mapper2.py  -file /content/reducer.py  -mapper 'python mapper2.py'  -reducer 'python reducer.py'
# Out:
# 2022-11-14 23:09:45,909 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [/content/mapper2.py, /content/reducer.py] [] /tmp/streamjob248373790864532489.jar tmpDir=null
# 2022-11-14 23:09:46,714 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2022-11-14 23:09:46,880 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2022-11-14 23:09:46,880 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2022-11-14 23:09:46,910 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2022-11-14 23:09:47,134 INFO mapred.FileInputFormat: Total input files to process : 1
# 2022-11-14 23:09:47,183 INFO mapreduce.JobSubmitter: number of splits:1
# 2022-11-14 23:09:47,515 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local1817316175_0001
# 2022-11-14 23:09:47,515 INFO mapreduce.JobSubmitter: Executing with tokens: []
# ...

# %%
# !ls /content/output/shakespeare2/
# Out:
# part-00000  _SUCCESS

# %%
# !head -n 15 /content/output/shakespeare2/part-00000
# Out:
# a	222
# abhor	2
# abide	3
# able	1
# about	9
# above	4
# absence	5
# absent	4
# abundance	4
# abundant	1
# abus	1
# abuse	3
# abuses	1
# abysm	1
# accents	1

# %% [markdown]
# ### MapReduce na coleção p2p_Gnutella.txt

# %% [markdown]
# #### Versão Inicial
#
# MapReduce apresentado em sala de aula (versão 2)

# %%
# !/usr/local/hadoop-3.3.4/bin/hadoop jar /usr/local/hadoop-3.3.4/share/hadoop/tools/lib/hadoop-streaming-3.3.4.jar -input /content/p2p-Gnutella08.txt -output /content/output/gnutella1 -file /content/mapper.py  -file /content/reducer.py  -mapper 'python mapper.py'  -reducer 'python reducer.py'
# Out:
# 2022-11-14 23:09:51,998 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [/content/mapper.py, /content/reducer.py] [] /tmp/streamjob4570558325599277353.jar tmpDir=null
# 2022-11-14 23:09:52,824 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2022-11-14 23:09:53,034 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2022-11-14 23:09:53,034 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2022-11-14 23:09:53,062 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2022-11-14 23:09:53,265 INFO mapred.FileInputFormat: Total input files to process : 1
# 2022-11-14 23:09:53,295 INFO mapreduce.JobSubmitter: number of splits:1
# 2022-11-14 23:09:53,644 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local235910465_0001
# 2022-11-14 23:09:53,644 INFO mapreduce.JobSubmitter: Executing with tokens: []
# ...

# %%
# !ls /content/output/gnutella1/
# Out:
# part-00000  _SUCCESS

# %%
# !head -n 15 /content/output/gnutella1/part-00000
# Out:
# #	4
# (each	1
# 0	10
# 1	1
# 10	7
# 100	4
# 1000	2
# 1001	20
# 1002	13
# 1003	4
# 1004	12
# 1005	13
# 1006	2
# 1007	4
# 1008	1

# %% [markdown]
# #### Versão Modificada

# %%
# !/usr/local/hadoop-3.3.4/bin/hadoop jar /usr/local/hadoop-3.3.4/share/hadoop/tools/lib/hadoop-streaming-3.3.4.jar -input /content/p2p-Gnutella08.txt -output /content/output/gnutella2 -file /content/mapper2_p2p.py  -file /content/reducer.py  -mapper 'python mapper2_p2p.py'  -reducer 'python reducer.py'
# Out:
# 2022-11-14 23:09:58,116 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [/content/mapper2_p2p.py, /content/reducer.py] [] /tmp/streamjob15380316308937719778.jar tmpDir=null
# 2022-11-14 23:09:59,002 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2022-11-14 23:09:59,231 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2022-11-14 23:09:59,231 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2022-11-14 23:09:59,260 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2022-11-14 23:09:59,472 INFO mapred.FileInputFormat: Total input files to process : 1
# 2022-11-14 23:09:59,510 INFO mapreduce.JobSubmitter: number of splits:1
# 2022-11-14 23:09:59,844 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local45576475_0001
# 2022-11-14 23:09:59,844 INFO mapreduce.JobSubmitter: Executing with tokens: []
# ...

# %%
# !ls /content/output/gnutella2/
# Out:
# part-00000  _SUCCESS

# %%
# !head -n 15 /content/output/gnutella2/part-00000
# Out:
# 0	10
# 1	1
# 10	7
# 100	4
# 1000	2
# 1001	20
# 1002	13
# 1003	4
# 1004	12
# 1005	13
# 1006	2
# 1007	4
# 1008	1
# 1009	11
# 101	14

# %% [markdown]
# ## Questões (coleção Shakespeare)

# %% [markdown]
# ### Questão 1
#
# Qual o número de palavras distintas na coleção?

# %%
# !wc -l /content/output/shakespeare1/part-00000 | awk '{print $1}'
# Out:
# 5261

# %% [markdown]
# ### Questão 2
#
# Liste as 10 palavras que mais ocorrem na coleção.

# %%
# !sort -k 2nr /content/output/shakespeare1/part-00000 | head -n 10
# Out:
# the	609
# and	556
# of	487
# to	485
# in	376
# my	371
# that	332
# i	327
# thy	280
# with	228

# %% [markdown]
# ### Questão 3
#
# Apresente um histograma da **frequência de ocorrência das palavras na coleção**. O histograma deverá ter $10$ classes, cada uma representando um intervalo de frequência. O formato do histograma deverá ser textual, e não gráfico. Por exemplo, seja $I_i$ o í-ésimo intervalo de frequência e $C_n$ número de palavras cuja frequência de ocorrência está no intervalo, o histograma teria o seguinte formato:
# - $I_1$ - $C_1$
# - $I_2$ - $C_2$
# - $I_n$ - $C_n$

# %%
from math import ceil


def histograma(arquivo):
    frequencia = dict()
    count_max = None
    count_min = None
    with open(arquivo) as f:
        _, count = f.readline().split('\t')
        count_max = int(count)
        count_min = count_max
        f.seek(0)
        for line in f:
            _, count = line.split('\t')
            count = int(count)
            frequencia[count] = 1 if count not in frequencia else frequencia[count] + 1
            if count > count_max:
                count_max = count
            if count < count_min:
                count_min = count
    step = ceil((count_max-count_min)/10)
    hist_data = [0]*10
    for count, qntd in frequencia.items():
        hist_data[(count-count_min)//step] += qntd
    for i, qntd in enumerate(hist_data):
        print('[', count_min+(step*i), ',', count_min + (step*(i+1))-1, '] - ', qntd,  sep='')

# %%
histograma('/content/output/shakespeare1/part-00000')
# Out:
# [1,61] - 5217
# [62,122] - 22
# [123,183] - 9
# [184,244] - 4
# [245,305] - 1
# [306,366] - 2
# [367,427] - 2
# [428,488] - 2
# [489,549] - 0
# [550,610] - 2

# %% [markdown]
# ### Questão 4
#
# (Usando a versão modificada) Qual o número de palavras distintas na coleção?

# %%
# !wc -l /content/output/shakespeare2/part-00000 | awk '{print $1}'
# Out:
# 3635

# %% [markdown]
# ### Questão 5
#
# (Usando a versão modificada) Liste as 10 palavras que mais ocorrem na coleção.

# %%
# !sort -k 2nr /content/output/shakespeare2/part-00000 | head -n 10
# Out:
# the	613
# and	560
# to	495
# of	488
# in	380
# my	372
# i	352
# that	338
# thy	281
# d	239

# %% [markdown]
# ### Questão 6
#
# (Usando a versão modificada) Apresente um histograma da **frequência de ocorrência das palavras na coleção**. O histograma deverá ter $10$ classes, cada uma representando um intervalo de frequência. O formato do histograma deverá ser textual, e não gráfico. Por exemplo, seja $I_i$ o í-ésimo intervalo de frequência e $C_n$ número de palavras cuja frequência de ocorrência está no intervalo, o histograma teria o seguinte formato:
# - $I_1$ - $C_1$
# - $I_2$ - $C_2$
# - $I_n$ - $C_n$

# %%
histograma('/content/output/shakespeare2/part-00000')
# Out:
# [1,62] - 3582
# [63,124] - 25
# [125,186] - 10
# [187,248] - 9
# [249,310] - 1
# [311,372] - 3
# [373,434] - 1
# [435,496] - 2
# [497,558] - 0
# [559,620] - 2

# %% [markdown]
# ## Questões (coleção p2p-Gnutella08)

# %% [markdown]
# ### Questão 1
#
# Qual o número de palavras distintas na coleção?

# %%
# !wc -l /content/output/gnutella1/part-00000 | awk '{print $1}'
# Out:
# 6324

# %% [markdown]
# ### Questão 2
#
# Liste as 10 palavras que mais ocorrem na coleção.

# %%
# !sort -k 2nr /content/output/gnutella1/part-00000 | head -n 10
# Out:
# 123	97
# 127	95
# 367	94
# 424	92
# 251	91
# 264	91
# 266	91
# 427	91
# 145	90
# 249	90

# %% [markdown]
# ### Questão 3
#
# Apresente um histograma da **frequência de ocorrência das palavras na coleção**. O histograma deverá ter $10$ classes, cada uma representando um intervalo de frequência. O formato do histograma deverá ser textual, e não gráfico. Por exemplo, seja $I_i$ o í-ésimo intervalo de frequência e $C_n$ número de palavras cuja frequência de ocorrência está no intervalo, o histograma teria o seguinte formato:
# - $I_1$ - $C_1$
# - $I_2$ - $C_2$
# - $I_n$ - $C_n$

# %%
histograma('/content/output/gnutella1//part-00000')
# Out:
# [1,10] - 4434
# [11,20] - 1775
# [21,30] - 45
# [31,40] - 7
# [41,50] - 12
# [51,60] - 7
# [61,70] - 9
# [71,80] - 15
# [81,90] - 12
# [91,100] - 8

# %% [markdown]
# ### Questão 4
#
# (Usando a versão modificada) Qual o número de palavras distintas na coleção?

# %%
# !wc -l /content/output/gnutella2/part-00000 | awk '{print $1}'
# Out:
# 6301

# %% [markdown]
# ### Questão 5
#
# (Usando a versão modificada) Liste as 10 palavras que mais ocorrem na coleção.

# %%
# !sort -k 2nr /content/output/gnutella2/part-00000 | head -n 10
# Out:
# 123	97
# 127	95
# 367	94
# 424	92
# 251	91
# 264	91
# 266	91
# 427	91
# 145	90
# 249	90

# %% [markdown]
# ### Questão 6
#
# (Usando a versão modificada) Apresente um histograma da **frequência de ocorrência das palavras na coleção**. O histograma deverá ter $10$ classes, cada uma representando um intervalo de frequência. O formato do histograma deverá ser textual, e não gráfico. Por exemplo, seja $I_i$ o í-ésimo intervalo de frequência e $C_n$ número de palavras cuja frequência de ocorrência está no intervalo, o histograma teria o seguinte formato:
# - $I_1$ - $C_1$
# - $I_2$ - $C_2$
# - $I_n$ - $C_n$

# %%
histograma('/content/output/gnutella2//part-00000')
# Out:
# [1,10] - 4411
# [11,20] - 1775
# [21,30] - 45
# [31,40] - 7
# [41,50] - 12
# [51,60] - 7
# [61,70] - 9
# [71,80] - 15
# [81,90] - 12
# [91,100] - 8
